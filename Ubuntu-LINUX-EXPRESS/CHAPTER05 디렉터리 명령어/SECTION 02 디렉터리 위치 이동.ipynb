# %% [markdown]
# 디렉터리 이동
#  - 우분투에서 사용자가 접근하지 못하도록 막아 놓은 디렉터리를 제외 모든 디렉터리 이동 가능
#  - cd :change directory 명령 사용
#
#  ```cli
#  cd Documents
#  ```
#  ![image.png](attachment:image.png)

# %% [markdown]
# # 1. 상대 경로명

# %% [markdown]
# 상위 디렉터리 이동
#
#     - cd ..
#
# ```cli
# cd ../Documents
# ```
# ![image.png](attachment:image.png)

# %% [markdown]
#  - cd ~ : 홈 디렉터리를 나타내는 기호인 ~를 사용 홈디렉터리로 이동
#  - cd : 이동할 목적지를 지정하지 않고 해당 계정의 홈 디렉터리로 이동
#  - cd /home/joung5846 : 절대 경로명을 사용하여 홈 디렉터리로 이동
#  - cd ../../home/joung5846 : 상대 경로명을 사용하여 홈 디렉터리로 이동

# %% [markdown]
# # 2. 홈 디렉터리
