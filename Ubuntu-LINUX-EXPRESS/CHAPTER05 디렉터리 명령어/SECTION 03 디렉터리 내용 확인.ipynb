# %% [markdown]
# ls 명령
#
#     - list의 의미로 현재 디렉터리에 있는 파일이나 서브 디렉터리의 목록을 보여주는 명령
#     - ls 명령 사용 특정 디렉터리에 어떠한 파일이나 서브 디렉터리가 존재하는지 확인
#
#  - 기능 : 디렉터리에 존재하는 파일이나 서브 디렉터리에 대한 정보 확인
#  - 형식 : ls[옵션] [파일명 또는 디렉터리명]
#
#  - 옵션
#      - -a : 숨겨진 파일까지 포함 모든 파일 리스트를 출력
#      - -d : 지정한 디렉터리에 존재하는 파일과 디렉터리의 정보 출력
#      - -n : 호스트네임 확인
#      - -i : 첫 번째 열에 I-node 번호를 출력
#      - -l : 파일의 상세한 정보를 출력
#      - -A : .와 ..를 제외한 모든 파일 리스트를 출력
#      - -F : 파일의 종류를 실행파일은 *, 디렉터리는 /, 심볼링 링크는 @ 표시
#      - -L : 심볼릭 링크 파일은 원본 파일의 정보를 표시
#      - -R : 하위 디렉터리 리스트 출력

# %% [markdown]
# ---

# %% [markdown]
# # 1. 현재 디렉터리 : ls

# %% [markdown]
# ---

# %% [markdown]
# # 2. 숨김 파일 확인 : ls -a

# %% [markdown]
# ---

# %% [markdown]
# # 3. 파일의 종류 확인 :ls -F

# %% [markdown]
# ---

# %% [markdown]
# # 4. 디렉터리 상세 정보 :ls -l

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # 5. 디렉터리의 자체정보 : ls -l

# %% [markdown]
# ---

# %% [markdown]
# # 6. I-node 번호 확인 : ls -i

# %% [markdown]
# ---

# %% [markdown]
# # 7. 심볼릭 링크  출력 : ls -l

# %% [markdown]
#  - 디렉터리의 내용을 살펴볼 때 사용하는 심볼릭 링크 명령 dir, vdir
#  - 도스 명령에서 디렉터리와 관련하여 주로 많이 사용 되었던 dir명령을
#    우분투에서도 쉽게 사용할 수 있도록 심볼릭 링크 명령으로 제공
#
#  - dir 명령은 ls 명령에 대한 심볼릭 링크이며 vdir 명령은 ls -l명령에 대한 심볼릭 링크

# %% [markdown]
# ---

# %% [markdown]
# # 8. 파일의 존재 확인: ls 파일명

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
