# %% [markdown]
# # 1. X윈도에서 실행

# %% [markdown]
# - [텍스트 편집기]는 UTF-8과의 호환성을 제공하며 프로그램 코딩, 마크업 언어와 같은
#   구조화된 텍스트 문서를 GUI 환경에서 편집하는 용도에 중점을 두고 개발된 에디터
#
# - X 윈도 화면에서 [텍스트 편집기] 아이콘을 클릭하면 텍스트를 편집할 수 있음
# - 터미널 창에서 gedit 명령으로 수행

# %% [markdown]
# # 2. 터미널 창에서 실행

# %% [markdown]
#  - 터미널 창에서 [텍스트 편집기]를 실행할 때는 gedit 명령을 사용

# %% [markdown]
# ### step01
# - mkdir 명령으로 실습할 chap_07디렉터리를 생성 후 디렉터리의 위치를
# - chap_07로 이동한 다음 gedit 명령으로 study.txt파일을 생성

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### step02
# - 텍스트 편집기 활성화 되면 다음 문장 입력
# ![image.png](attachment:image.png)

# %% [markdown]
# ### step03
# - 텍스트 편집기 창에서 저장을 누른 다음 텍스트 편집창은 닫아줍니다.

# %% [markdown]
# ### step04
#  - cat 명령과 옵션 -n을 사용하여 study.txt 파일의 내용을 행 번호와 함께 출력

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### step05
# - study.txt 파일의 내용에 다음 문장을 추가하기 위해 gedit 명령을 수행

# %% [markdown]
# ### step06
#  - cat 명령과 -n을 사용하여 변경된 study.txt 파일의 내용을 출력

# %% [markdown]
# ![image.png](attachment:image.png)
